# %% [markdown]
# # Task_4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script contains: Step 1 - Step 9

# %% [markdown]
# ### Step 1 - Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Define path

path = '/Users/mariasampogna/Documents/Career Foundry/Data Analytics Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# Import ords_prods_merge datafram

ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_new_columns.pkl'))

# %%
# Check the output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# ### Step 2 - In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# calculate the mean of the “order_number” column grouped by the “department_id” column

ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# ### Step 3 - Analyze the result. How do the results for the entire dataframe differ from those of the subset?

# %% [markdown]
# The mean values for the entire dataframe are different from the subset, because many more values are being aggregated in the entire dataframe. It looks like the mean values here are generally higher than in the subset, likely because more order number values (and higher values) were included in the entire dataframe.

# %% [markdown]
# ### Step 4 - Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# create a max_order column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# check the results

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# create a flag to assign loyalty based on the max number of orders

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# check the results

ords_prods_merge[['user_id', 'max_order', 'loyalty_flag']].head(60)
# Out:
#     user_id  max_order      loyalty_flag
# 0         1         10      New customer
# 1         1         10      New customer
# 2         1         10      New customer
# 3         1         10      New customer
# 4         1         10      New customer
# 5         1         10      New customer
# 6         1         10      New customer
# 7         1         10      New customer
# 8         1         10      New customer
# 9         1         10      New customer
# 10        1         10      New customer
# 11        1         10      New customer
# 12        1         10      New customer
# 13        1         10      New customer
# 14        1         10      New customer
# 15        1         10      New customer
# 16        1         10      New customer
# 17        1         10      New customer
# 18        1         10      New customer
# 19        1         10      New customer
# 20        1         10      New customer
# 21        1         10      New customer
# ...

# %% [markdown]
# ### Step 5 - Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).

# %%
# calculate the mean, min, and max of the “prices” column grouped by the “loyalty_flag” column

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### Step 6 - Create a spending flag for each user based on the average price across all their orders using the following criteria:
# #### If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# #### If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# create a mean_price column

ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# check the output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered  ... department_id  prices  _merge    price_range_loc  \
# ...

# %%
# create a flag based on mean spending for each user

ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# check the output

ords_prods_merge[['user_id', 'mean_price', 'spending_flag']].head(60)
# Out:
#     user_id  mean_price spending_flag
# 0         1    6.367797   Low spender
# 1         1    6.367797   Low spender
# 2         1    6.367797   Low spender
# 3         1    6.367797   Low spender
# 4         1    6.367797   Low spender
# 5         1    6.367797   Low spender
# 6         1    6.367797   Low spender
# 7         1    6.367797   Low spender
# 8         1    6.367797   Low spender
# 9         1    6.367797   Low spender
# 10        1    6.367797   Low spender
# 11        1    6.367797   Low spender
# 12        1    6.367797   Low spender
# 13        1    6.367797   Low spender
# 14        1    6.367797   Low spender
# 15        1    6.367797   Low spender
# 16        1    6.367797   Low spender
# 17        1    6.367797   Low spender
# 18        1    6.367797   Low spender
# 19        1    6.367797   Low spender
# 20        1    6.367797   Low spender
# 21        1    6.367797   Low spender
# 22        1    6.367797   Low spender
# 23        1    6.367797   Low spender
# ...

# %% [markdown]
# ### Step 7 - Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# create a median_days_since_prior_order column

ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# check the output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered  ... _merge    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
# create a flag to assign frequency based on the median days since prior order

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20) & (ords_prods_merge['median_days_since_prior_order'] > 10), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# check the output

ords_prods_merge[['user_id', 'median_days_since_prior_order', 'frequency_flag']].head(60)
# Out:
#     user_id  median_days_since_prior_order         frequency_flag
# 0         1                           20.5  Non-frequent customer
# 1         1                           20.5  Non-frequent customer
# 2         1                           20.5  Non-frequent customer
# 3         1                           20.5  Non-frequent customer
# 4         1                           20.5  Non-frequent customer
# 5         1                           20.5  Non-frequent customer
# 6         1                           20.5  Non-frequent customer
# 7         1                           20.5  Non-frequent customer
# 8         1                           20.5  Non-frequent customer
# 9         1                           20.5  Non-frequent customer
# 10        1                           20.5  Non-frequent customer
# 11        1                           20.5  Non-frequent customer
# 12        1                           20.5  Non-frequent customer
# ...

# %% [markdown]
# ### Step 9 - Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# export pickle file

ords_prods_merge.to_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_merge_flags.pkl'))

# %% [markdown]
# ### From 4.9 - Removing Outliers from Prices

# %%
# import most recent data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_flags.pkl'))

# %%
# check for prices that are not "normal"

ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 1576        912404       17            12                  2
# 1638        603376       17            22                  6
# 16534      3264360      135             2                  2
# 16540       892534      135             3                  0
# 53712       229704      342             8                  1
# ...            ...      ...           ...                ...
# 32350634   3172853   205650            18                  1
# 32377867   2504315   205818             3                  5
# 32377877   1108388   205818             5                  4
# 32410707   1916142   206049             1                  2
# 32410731    379732   206049             4                  1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 1576                     14                     5.0        False       21553
# ...

# %%
# turn the values over 100 into NAs

ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
# check the output

ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# export cleaned data to pickle file

ords_prods_merge.to_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_merge_flags_clean.pkl'))
