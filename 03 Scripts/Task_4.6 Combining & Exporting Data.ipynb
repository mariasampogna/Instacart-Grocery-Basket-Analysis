# %% [markdown]
# ## 4.6: Combining & Exporting Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Step 3 - In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Define file path

path = '/Users/mariasampogna/Documents/Career Foundry/Data Analytics Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# Import pickle file

df_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check the output

df_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           0   2539329        1             1                  2
# 2           0   2539329        1             1                  2
# 3           0   2539329        1             1                  2
# 4           0   2539329        1             1                  2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  8                     NaN         True       14084
# 2                  8                     NaN         True       12427
# 3                  8                     NaN         True       26088
# 4                  8                     NaN         True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_combined['product_id'].value_counts()[26520]
# Out:
# 562

# %% [markdown]
# ### Step 4 - Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
# Check the shape of the dataframe

df_combined.shape
# Out:
# (32434489, 12)

# %% [markdown]
# ### Step 5 - Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
# import products dataset

df_products = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked.csv'), index_col=False)

# %%
# counting unique values
n = len(pd.unique(df_products['product_id']))
  
print("No.of.unique values :", 
      n)
# Out:
# No.of.unique values : 49670

# %%
# Count duplicate on a column
df_products.product_id.duplicated().sum()
# Out:
# 2

# %%
df_prod_id_dups = df_products[df_products.product_id.duplicated()]

# %%
df_prod_id_dups.head()
# Out:
#        Unnamed: 0  product_id                                  product_name  \
# 6785         6800        6800            Sprouted Quinoa Flakes Baby Cereal
# 26505       26521       26520  Cheese Shredded Sharp Cheddar Reduced Fat 2%
#
#        aisle_id  department_id  prices
# 6785         92             18    14.0
# 26505        21             16     2.9

# %%
df_products['product_id'].value_counts()[26520]
# Out:
# 2

# %%
df_products.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24852.005053  24850.349775     67.762442      11.728942      9.993282
# std    14342.265579  14340.705287     38.315784       5.850779    453.615536
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000  12432.750000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.250000  37268.250000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000  99999.000000

# %%
# check the output

df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products.shape
# Out:
# (49672, 6)

# %%
# drop the merge column from the combined dataset

df_combined = df_combined.drop(columns=['Unnamed: 0', '_merge'])

# %%
df_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_combined.shape
# Out:
# (32434489, 10)

# %%
# drop the unnamed column from the products dataset

df_products = df_products.drop(columns=['Unnamed: 0'])

# %%
df_dups = df_products[df_products.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id, prices]
# Index: []

# %%
df_dups_2 = df_combined[df_combined.duplicated()]

# %%
df_dups_2
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# use a left merge to merge the two datasets

df_merged_left = pd.merge(df_combined, df_products, on = ['product_id'], how = 'left', indicator = True)

# %%
# check the output

df_merged_left.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_merged_left.tail()
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 32435054   2977660   206209            13                  1
# 32435055   2977660   206209            13                  1
# 32435056   2977660   206209            13                  1
# 32435057   2977660   206209            13                  1
# 32435058   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 32435054                 12                     7.0        False       14197
# 32435055                 12                     7.0        False       38730
# 32435056                 12                     7.0        False       31477
# 32435057                 12                     7.0        False        6567
# 32435058                 12                     7.0        False       22920
#
#           add_to_cart_order  reordered                           product_name  \
# ...

# %%
# use an inner merge to merge the two datasets

df_merged_inner = pd.merge(df_combined, df_products, on = ['product_id'], indicator = True)

# %%
df_merged_inner.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ### Step 6 - Confirm the results of the merge using the merge flag.

# %%
# check the count of merge values

df_merged_left['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_left.shape
# Out:
# (32435059, 15)

# %%
df_dups_3 = df_merged_left[df_merged_left.duplicated()]

# %%
df_dups_3
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge]
# Index: []

# %%
df_merged_left.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_hour_of_day               0
# days_since_prior_order    2078102
# first_order                     0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                30200
# aisle_id                    30200
# department_id               30200
# prices                      30200
# _merge                          0
# dtype: int64

# %%
df_combined.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_hour_of_day               0
# days_since_prior_order    2078068
# first_order                     0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# dtype: int64

# %%
# create a dataframe to include the null product name values to review them

df_nan = df_merged_left[df_merged_left['product_name'].isnull()==True]

# %%
# check the output

df_nan.head(15)
# Out:
#        order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 2963       7099       27            63                  3                 10
# 3205    1837192       27            80                  2                  8
# 3253    3331846       28             3                  0                 16
# 3395    1385910       28            21                  2                 17
# 4694    2873174       38             1                  0                 10
# 4714    1308004       38             2                  4                 11
# 6409    1520353       52            10                  2                 10
# 6425    2906390       52            13                  1                 10
# 6588    3337837       54             3                  4                 18
# 6646    2205320       54            10                  2                  9
# 10381   2139400       81             6                  3                  7
# ...

# %% [markdown]
# ### Step 7 - Export the newly created dataframe as orders_products_merged in a suitable format

# %%
# Export pickle file

df_merged_left.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_details.pkl'))
