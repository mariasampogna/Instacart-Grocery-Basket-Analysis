# %% [markdown]
# ## 4.7 Deriving New Variables

# %% [markdown]
# ### This script contains:
# ### EXERCISE
# #### 1. Import data
# #### 2. If-Statements with User-Defined Functions
# #### 3. If-Statements with the loc() Funtion
# #### 4. If-Statements with For-Loops
# ### TASK
# #### Steps 2-7

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### EXERCISE

# %% [markdown]
# #### 1. Import Data

# %%
# define path

path = '/Users/mariasampogna/Documents/Career Foundry/Data Analytics Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# import merged dataset

ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_details.pkl'))

# %%
# create a smaller subset to work with for now

df = ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# #### 2. If-Statements with User-Defined Functions

# %%
# define price_label function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/d6/4mhjj43j7r9_r1lf0ncld46h0000gn/T/ipykernel_66170/2698948789.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# #### 3. If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/d6/4mhjj43j7r9_r1lf0ncld46h0000gn/T/ipykernel_66170/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     672525
# Low-range product     314109
# High-range product     12413
# NaN                      953
# Name: price_range_loc, dtype: int64

# %%
# use loc funtion on entire dataset

ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-Range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-Range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged_new = ords_prods_merged.loc[ords_prods_merged['price_range_loc'].isin(['Mid-Range product', 'Low-range product', 'High-range product'])]

# %%
ords_prods_merged_new['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-Range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #### 4. If-Statements with For-Loops

# %%
ords_prods_merged_new.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# get frequency of each day of week

ords_prods_merged_new['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
# create a list of business usig a for-loop

result = []

for value in ords_prods_merged_new["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# print the results

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# create a new column using this list

ords_prods_merged_new['busiest_day'] = result
# Out:
# /var/folders/d6/4mhjj43j7r9_r1lf0ncld46h0000gn/T/ipykernel_66170/545977808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ords_prods_merged_new['busiest_day'] = result

# %%
ords_prods_merged_new['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ### TASK

# %% [markdown]
# #### Step 2 - Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# create a list of business using a for-loop

result = []

for value in ords_prods_merged_new["order_day_of_week"]:
  if value in[0, 1]:
    result.append("Busiest days")
  elif value in[3, 4]:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
# print the results

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %%
# create a new column using this list

ords_prods_merged_new['busiest_days'] = result
# Out:
# /var/folders/d6/4mhjj43j7r9_r1lf0ncld46h0000gn/T/ipykernel_66170/1140753117.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ords_prods_merged_new['busiest_days'] = result

# %% [markdown]
# #### Step 3 - Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# check the output

ords_prods_merged_new['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %%
# check the math for the two busiest days

print(6204182 + 5660230)
# Out:
# 11864412

# %%
# check the math for the slowest days

print(3840534 + 3783802)
# Out:
# 7624336

# %%
# check the math for regular busy days

print(4496490 + 4213830 + 4205791)
# Out:
# 12916111

# %% [markdown]
# These values look correct based on the counts found earlier for the frequency of each day of the week

# %% [markdown]
# #### Step 4 - When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# get frequency of each hour of the day

ords_prods_merged_new['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# create a list of business using a for-loop

result = []

for value in ords_prods_merged_new["order_hour_of_day"]:
  if value in[0, 1, 2, 3, 4, 5]:
    result.append("Fewest orders")
  elif value in[10, 11, 12, 13, 14, 15]:
    result.append("Most orders")
  else:
    result.append("Average orders")

# %%
# print the results

result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
# create a new column using this list

ords_prods_merged_new['busiest_period_of_day'] = result
# Out:
# /var/folders/d6/4mhjj43j7r9_r1lf0ncld46h0000gn/T/ipykernel_66170/1708003041.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ords_prods_merged_new['busiest_period_of_day'] = result

# %% [markdown]
# #### Step 5 - Print the frequency for this new column.

# %%
# check the frequency

ords_prods_merged_new['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       16128666
# Average orders    15679865
# Fewest orders       596328
# Name: busiest_period_of_day, dtype: int64

# %%
# check the math for most orders

print(2761760 + 2736140 + 2689136 + 2662144 + 2660954 + 2618532)
# Out:
# 16128666

# %%
# check the math for least orders

print(218769 + 115700 + 87961 + 69375 + 53242 + 51281)
# Out:
# 596328

# %% [markdown]
# #### Step 7 - Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merged_new.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_new_columns.pkl'))
